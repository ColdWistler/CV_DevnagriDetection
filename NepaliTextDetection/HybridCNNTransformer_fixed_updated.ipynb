# %%
# !pip install matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: matplotlib in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (3.9.4)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: scipy>=1.6.0 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 19.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading pandas-2.2.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 20.5 MB/s eta 0:00:000:00:01 eta 0:00:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, threadpoolctl, joblib, scikit-learn, pandas, seaborn
# Successfully installed joblib-1.4.2 pandas-2.2.3 scikit-learn-1.6.1 seaborn-0.13.2 threadpoolctl-3.5.0 tzdata-2025.1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Reshape, MultiHeadAttention, LayerNormalization, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard

# Paths for dataset and logging
BASE_DIR = "/home/soggygenus/Documents/CV/devanagari-character-recognition"
TRAIN_DIR = f"{BASE_DIR}/train/"
TEST_DIR = f"{BASE_DIR}/test/"
LOG_DIR = f"{BASE_DIR}/logs"

# Data preprocessing with augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1.0/255)

training_set = train_datagen.flow_from_directory(
    TRAIN_DIR, target_size=(32, 32), batch_size=100, class_mode='categorical'
)

test_set = test_datagen.flow_from_directory(
    TEST_DIR, target_size=(32, 32), batch_size=100, class_mode='categorical', shuffle=False
)

num_classes = len(training_set.class_indices)

# Compute class weights
y_train = training_set.classes
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# Define the CNN-Transformer hybrid model
input_shape = (32, 32, 3)
inputs = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu')(inputs)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(x)
x = Dropout(0.25)(x)
x = Flatten()(x)

sequence_length = x.shape[-1] // 64
x = Reshape((sequence_length, 64))(x)

num_heads = 8
ff_dim = 128

attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=ff_dim // num_heads)(x, x)
attention_output = LayerNormalization(epsilon=1e-6)(attention_output + x)

ff_output = Dense(ff_dim, activation="relu")(attention_output)
ff_output = Dense(64)(ff_output)
ff_output = LayerNormalization(epsilon=1e-6)(ff_output + attention_output)

x = GlobalAveragePooling1D()(ff_output)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs, outputs)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

tensorboard_callback = TensorBoard(log_dir=LOG_DIR, write_graph=True, write_images=True)

history = model.fit(
    training_set,
    steps_per_epoch=len(training_set),
    epochs=50,
    validation_data=test_set,
    validation_steps=len(test_set),
    class_weight=class_weight_dict,
    callbacks=[tensorboard_callback]
)

model.save("devnagri_character_model_hybrid.keras")

# Evaluate model
test_loss, test_accuracy = model.evaluate(test_set, steps=len(test_set))
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Generate confusion matrix
y_pred = model.predict(test_set, steps=len(test_set))
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_set.classes[:len(y_pred_classes)]

cm = confusion_matrix(y_true, y_pred_classes)
cm_df = pd.DataFrame(cm, index=training_set.class_indices.keys(), columns=training_set.class_indices.keys())
cm_df.to_csv("confusion_matrix.csv", index=True)

# Plot accuracy and loss curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Curve')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Curve')
plt.show()

# Plot confusion matrix
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=training_set.class_indices.keys(), yticklabels=training_set.class_indices.keys())
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Plot class-wise accuracy
class_accuracies = cm.diagonal() / cm.sum(axis=1)
plt.figure(figsize=(12, 6))
plt.bar(training_set.class_indices.keys(), class_accuracies)
plt.xlabel("Class")
plt.ylabel("Accuracy")
plt.title("Class-wise Accuracy")
plt.xticks(rotation=90)
plt.show()

print("Confusion matrix saved as confusion_matrix.csv")
# Out:
# 2025-03-19 19:16:09.964966: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742391070.074687   25464 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742391070.094823   25464 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-19 19:16:10.212174: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 78200 images belonging to 46 classes.
# Found 13800 images belonging to 46 classes.
# I0000 00:00:1742391075.366489   25464 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4596 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5
# /home/soggygenus/miniconda3/envs/jupyter_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742391081.036813   36033 service.cc:148] XLA service 0x71063c0167a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742391081.036835   36033 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2060, Compute Capability 7.5
# 2025-03-19 19:16:21.114401: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742391081.700514   36033 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-19 19:16:22.738293: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,32,30,30]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,3,32,32]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-19 19:16:22.785476: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,64,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,32,30,30]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-19 19:16:22.914037: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,64,12,12]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,14,14]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-19 19:16:23.006686: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,64,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,12,12]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
#   3/782 ━━━━━━━━━━━━━━━━━━━━ 53s 69ms/step - accuracy: 0.0356 - loss: 4.2613
# I0000 00:00:1742391087.041390   36033 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2686 - loss: 2.7621
# 2025-03-19 19:17:37.639550: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,32,30,30]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,3,32,32]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-19 19:17:37.658693: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,64,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,32,30,30]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-19 19:17:37.774812: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,64,12,12]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,14,14]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-03-19 19:17:37.857575: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[100,64,10,10]{3,2,1,0}, u8[0]{0}) custom-call(f32[100,64,12,12]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 95ms/step - accuracy: 0.2689 - loss: 2.7609 - val_accuracy: 0.8977 - val_loss: 0.3880
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.8142 - loss: 0.6147 - val_accuracy: 0.9371 - val_loss: 0.2115
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 80ms/step - accuracy: 0.8796 - loss: 0.3934 - val_accuracy: 0.9631 - val_loss: 0.1228
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9084 - loss: 0.3022 - val_accuracy: 0.9678 - val_loss: 0.1091
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9252 - loss: 0.2439 - val_accuracy: 0.9695 - val_loss: 0.1003
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9319 - loss: 0.2255 - val_accuracy: 0.9771 - val_loss: 0.0740
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9391 - loss: 0.2035 - val_accuracy: 0.9778 - val_loss: 0.0732
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9438 - loss: 0.1856 - val_accuracy: 0.9826 - val_loss: 0.0598
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.9462 - loss: 0.1716 - val_accuracy: 0.9835 - val_loss: 0.0541
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9510 - loss: 0.1627 - val_accuracy: 0.9817 - val_loss: 0.0579
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9546 - loss: 0.1512 - val_accuracy: 0.9852 - val_loss: 0.0491
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9569 - loss: 0.1420 - val_accuracy: 0.9819 - val_loss: 0.0601
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 89ms/step - accuracy: 0.9564 - loss: 0.1399 - val_accuracy: 0.9872 - val_loss: 0.0444
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9615 - loss: 0.1292 - val_accuracy: 0.9880 - val_loss: 0.0432
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.9609 - loss: 0.1298 - val_accuracy: 0.9867 - val_loss: 0.0451
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.9636 - loss: 0.1212 - val_accuracy: 0.9873 - val_loss: 0.0426
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9645 - loss: 0.1154 - val_accuracy: 0.9891 - val_loss: 0.0350
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9658 - loss: 0.1147 - val_accuracy: 0.9879 - val_loss: 0.0425
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9656 - loss: 0.1145 - val_accuracy: 0.9911 - val_loss: 0.0333
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9671 - loss: 0.1079 - val_accuracy: 0.9888 - val_loss: 0.0369
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9706 - loss: 0.0983 - val_accuracy: 0.9869 - val_loss: 0.0464
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9703 - loss: 0.1003 - val_accuracy: 0.9896 - val_loss: 0.0362
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9719 - loss: 0.0936 - val_accuracy: 0.9884 - val_loss: 0.0368
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9712 - loss: 0.0948 - val_accuracy: 0.9887 - val_loss: 0.0380
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9714 - loss: 0.0946 - val_accuracy: 0.9885 - val_loss: 0.0370
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9714 - loss: 0.0924 - val_accuracy: 0.9916 - val_loss: 0.0292
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9730 - loss: 0.0901 - val_accuracy: 0.9907 - val_loss: 0.0310
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9740 - loss: 0.0900 - val_accuracy: 0.9894 - val_loss: 0.0345
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9734 - loss: 0.0889 - val_accuracy: 0.9899 - val_loss: 0.0359
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9755 - loss: 0.0821 - val_accuracy: 0.9904 - val_loss: 0.0332
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9754 - loss: 0.0829 - val_accuracy: 0.9907 - val_loss: 0.0315
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9749 - loss: 0.0818 - val_accuracy: 0.9915 - val_loss: 0.0301
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9748 - loss: 0.0818 - val_accuracy: 0.9914 - val_loss: 0.0267
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9770 - loss: 0.0798 - val_accuracy: 0.9914 - val_loss: 0.0284
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9771 - loss: 0.0758 - val_accuracy: 0.9896 - val_loss: 0.0355
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9767 - loss: 0.0772 - val_accuracy: 0.9904 - val_loss: 0.0312
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9771 - loss: 0.0751 - val_accuracy: 0.9917 - val_loss: 0.0289
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9765 - loss: 0.0786 - val_accuracy: 0.9902 - val_loss: 0.0334
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9785 - loss: 0.0726 - val_accuracy: 0.9923 - val_loss: 0.0270
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9795 - loss: 0.0691 - val_accuracy: 0.9904 - val_loss: 0.0294
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9789 - loss: 0.0712 - val_accuracy: 0.9912 - val_loss: 0.0293
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9793 - loss: 0.0702 - val_accuracy: 0.9909 - val_loss: 0.0289
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9779 - loss: 0.0726 - val_accuracy: 0.9908 - val_loss: 0.0282
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9786 - loss: 0.0712 - val_accuracy: 0.9927 - val_loss: 0.0257
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9803 - loss: 0.0677 - val_accuracy: 0.9902 - val_loss: 0.0321
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9800 - loss: 0.0672 - val_accuracy: 0.9912 - val_loss: 0.0274
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9802 - loss: 0.0689 - val_accuracy: 0.9922 - val_loss: 0.0288
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9812 - loss: 0.0648 - val_accuracy: 0.9913 - val_loss: 0.0288
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9804 - loss: 0.0650 - val_accuracy: 0.9925 - val_loss: 0.0282
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9797 - loss: 0.0669 - val_accuracy: 0.9915 - val_loss: 0.0325
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9906 - loss: 0.0375
# Test Loss: 0.032464127987623215
# Test Accuracy: 0.9915217161178589
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# Confusion matrix saved as confusion_matrix.csv
